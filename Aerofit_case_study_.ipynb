# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aerofit_treadmill.csv')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe(include=['object'])
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe(include=['object'])
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %% [markdown]
# Observation:
#
#
# *   missing value in the data found(180 non-null items are found)
# *   3 unique products are found
# *   KP281 is the highly used item
# *   The Aerofit products are more popular in Male compartively.
# *   Aerofit products are more popular among married people

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.describe()['Miles']
# Out:
# count    180.000000
# mean     103.194444
# std       51.863605
# min       21.000000
# 25%       66.000000
# 50%       94.000000
# 75%      114.750000
# max      360.000000
# Name: Miles, dtype: float64

# %%
#Get count of males and females
sns.countplot(x='Gender',data=df)

# %%
#Get usage of product across male and female
sns.countplot(x='Gender',hue='Product',data=df)

# %%
#Get insight of relation of product with married status
sns.countplot(x='MaritalStatus',hue='Product',data=df)

# %% [markdown]
# Observtion:
#
# 1.KP281 is highly popular among mamrried people
# 2.KP481 is more popular among 25 age group people whereas KP281 is more popular among 23 age people

# %%
#Agewise distribution
sns.countplot(x='Age',hue='Product',data=df)

# %% [markdown]
# Observation:KP481 is used nmostly by 25 aged group
# KP281 is used mostly by 23 aged people

# %%
product=df['Product'].value_counts().reset_index()
product
# Out:
#    index  Product
# 0  KP281       80
# 1  KP481       60
# 2  KP781       40

# %%
data = list(product['Product'])
keys = list(product['index'])
plt.pie(data, labels=keys, autopct='%.0f%%')
plt.title('Product Distribution')
plt.show()

# %%
data = list(product['Product'])
keys = list(product['index'])
plt.pie(data, labels=keys, autopct='%.0f%%')
plt.title('Product Distribution')
plt.show()

# %%
Gender=df['Gender'].value_counts().reset_index()
Gender
data = list(Gender['Gender'])
keys = list(Gender['index'])
plt.pie(data, labels=keys, autopct='%.0f%%')
plt.title('Gender Distribution')
plt.show()

# %%
age=df['Age'].value_counts().reset_index()
Gender
data = list(age['Age'])
keys = list(age['index'])
plt.pie(data, labels=keys, autopct='%.0f%%')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Observation:
# Aerofit are more popular with 25 aged group followed by 23,24,26 etc..

# %%
fit=df['Fitness'].value_counts().reset_index()
Gender
data = list(fit['Fitness'])
keys = list(fit['index'])
plt.pie(data, labels=keys, autopct='%.0f%%')
plt.title('Fitness Distribution')
plt.show()

# %%
#Bivariant Analysis
#Relating fitness with age-income
df_age_income=df.groupby('Age')['Income'].nunique().reset_index()
#df_age_income.sort_values('Income',ascending=False)
plt.xlabel("Income",fontsize=17)
plt.ylabel("Age",fontsize=17)
sns.boxplot(x= 'Income', y='Age', data=df_age_income)
plt.show()

# %% [markdown]
# Observation:
# More people found in Income segment four who is between 20 and 40

# %%
#Relating Gender~Age 
plt.figure(figsize=(10,5))
plt.xlabel("Fitness",fontsize=17)
plt.ylabel("Age",fontsize=17)
sns.boxplot(x= 'Fitness', y='Age', data=df)
plt.show()

# %% [markdown]
# Fitness 3 level are maintained by most of the people with range from 20 to 48 with average being used by people in 24-34 age group.

# %%
sns.set(font_scale = 1.1)
plt.figure(figsize=(10,5))
plt.xlabel("Gender",fontsize=17)
plt.ylabel("Miles",fontsize=17)
sns.boxplot(x= 'Gender', y='Miles', data=df)
plt.title("Miles and Gender based Customer distribution",fontdict ={"fontsize": 17})
plt.show()

# %% [markdown]
# Range of Female is 200 upper and around 49 lower with average around IQR range as 50 whereas for female it is 30 IQR with upper range as 125 and lower range as less than 25

# %%
plt.figure(figsize=(7,6))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
sns.pairplot(df, hue ='Product')

# %%
for col in ['Age', 'Income', 'Miles']:  
    sns.distplot(df[col])
#     plt.legend()
    plt.title(f'{col} Distribution')
    plt.show()
    plt.figure(figsize=(5,4))
    kp281 = df[df['Product']=='KP281']
    kp481 = df[df['Product']=='KP481']
    kp781 = df[df['Product']=='KP781']
    sns.distplot(kp281[col])
    sns.distplot(kp481[col])
    sns.distplot(kp781[col])
    plt.legend(['KP281', 'KP481', 'KP781'])
    plt.title(f'{col} distribution on product')
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ##Outlier Detection

# %%
IQR = np.percentile(df["Miles"],75) - np.percentile(df["Miles"],25)
Q3 = np.percentile(df["Miles"],75)
Q1 = np.percentile(df["Miles"],25)
UpperWhisker = Q3 + (1.5*(IQR))
UpperWhisker
# Out:
# 187.875

# %%
outlier= df[df["Miles"]>UpperWhisker]
len(outlier)
# Out:
# 0

# %% [markdown]
# Customers with more than 187.875 outlier is 0

# %%
(outlier['Product']>UpperWhisker).value_counts()
# Out:
# Series([], Name: Product, dtype: int64)

# %%
outlier
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 23    KP281   24  Female         16     Partnered      5        5   44343
# 84    KP481   21  Female         14     Partnered      5        4   34110
# 142   KP781   22    Male         18        Single      4        5   48556
# 148   KP781   24  Female         16        Single      5        5   52291
# 152   KP781   25  Female         18     Partnered      5        5   61006
# 155   KP781   25    Male         18     Partnered      6        5   75946
# 166   KP781   29    Male         14     Partnered      7        5   85906
# 167   KP781   30  Female         16     Partnered      6        5   90886
# 170   KP781   31    Male         16     Partnered      6        5   89641
# 171   KP781   33  Female         18     Partnered      4        5   95866
# 173   KP781   35    Male         16     Partnered      4        5   92131
# 175   KP781   40    Male         21        Single      6        5   83416
# ...

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Gender",fontsize=17)
plt.ylabel("Density",fontsize=17)
sns.distplot(df["Income"])
plt.title("Income based Customer distribution")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# More people are distributed between 40000 and 60000 income

# %%
#Income based outlier detection
IQR = np.percentile(df["Income"],75) - np.percentile(df["Income"],25)
Q3 = np.percentile(df["Income"],75)
Q1 = np.percentile(df["Income"],25)
UpperWhisker = Q3 + (1.5*(IQR))
UpperWhisker
# Out:
# 80581.875

# %% [markdown]
# People with more than 80581.875 income is 19

# %%
(df['Income']>UpperWhisker).value_counts()
# Out:
# False    161
# True      19
# Name: Income, dtype: int64

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
product_group_df = df.groupby(['Product']).agg({'Age': 'value_counts'}).rename(columns={'Product':'Product','Age': 'Age','Age':'COUNT'}).reset_index()

# %%
product_group_df
# Out:
#    Product  Age  COUNT
# 0    KP281   23      8
# 1    KP281   25      7
# 2    KP281   26      7
# 3    KP281   28      6
# 4    KP281   24      5
# ..     ...  ...    ...
# 63   KP781   40      1
# 64   KP781   42      1
# 65   KP781   45      1
# 66   KP781   47      1
# 67   KP781   48      1
#
# [68 rows x 3 columns]

# %%
df1 = df[['Product', 'Gender', 'MaritalStatus']].melt()
df1
df1.groupby(['variable', 'value'])[['value']].count() / len(df)
# Out:
#                             value
# variable      value
# Gender        Female     0.422222
#               Male       0.577778
# MaritalStatus Partnered  0.594444
#               Single     0.405556
# Product       KP281      0.444444
#               KP481      0.333333
#               KP781      0.222222

# %% [markdown]
# Obervations
# Product
#
#
# *   customers have purchased KP2821 product-44.44%
# *   customers have purchased KP481 product-33.33%
# *   customers have purchased KP781 product-22.22%
#
# Gender
# 57.78% of the customers are Male.
#
# MaritalStatus
#
#
# *   Partnered customer-59.44%

# %%
attrs = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
sns.set_style("white")
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
fig.subplots_adjust(top=1.2)
count = 0
for i in range(2):
    for j in range(3):
        sns.boxplot(data=df, x='Product', y=attrs[count], ax=axs[i,j], palette='Set3')
        axs[i,j].set_title(f"Product vs {attrs[count]}", pad=12, fontsize=13)
        count += 1

# %% [markdown]
# ###Observations
#
# 1.   Product vs Age
#
#
# *   Customers purchasing products KP281 & KP481 are having same Age median
# *   Customers whose age lies between 25-30, are more likely to buy KP781 product
#
#
#
# 2.   Product vs Education
#
# Customers whose Education is greater than 16, have more chances to purchase the KP781 product.
# 3.   Product vs Usage
#
# While the customers with Education less than 16 have equal chances of purchasing KP281 or KP481.
# 4.   Product vs Fitness
#
# The more the customer is fit (fitness >= 3), higher the chances of the customer to purchase the KP781 product.
#
# 5.   Product vs Income
#
# Higher the Income of the customer (Income >= 60000), higher the chances of the customer to purchase the KP781 product.
#
# 6.   Product vs Miles
#
# If the customer expects to walk/run greater than 120 Miles per week, it is more likely that the customer will buy KP781 product.

# %%
pd.crosstab(df['Product'],[df['MaritalStatus']], normalize=True, margins=True, margins_name='Total').round(2)
# Out:
# MaritalStatus  Partnered  Single  Total
# Product
# KP281               0.27    0.18   0.44
# KP481               0.20    0.13   0.33
# KP781               0.13    0.09   0.22
# Total               0.59    0.41   1.00

# %%
pd.crosstab(df['Product'],[df['Gender']], normalize=True, margins=True, margins_name='Total').round(2)
# Out:
# Gender   Female  Male  Total
# Product
# KP281      0.22  0.22   0.44
# KP481      0.16  0.17   0.33
# KP781      0.04  0.18   0.22
# Total      0.42  0.58   1.00

# %%
pd.crosstab(df['Product'],[df['Fitness']], normalize=True, margins=True, margins_name='Total').round(2)
# Out:
# Fitness     1     2     3     4     5  Total
# Product
# KP281    0.01  0.08  0.30  0.05  0.01   0.44
# KP481    0.01  0.07  0.22  0.04  0.00   0.33
# KP781    0.00  0.00  0.02  0.04  0.16   0.22
# Total    0.01  0.14  0.54  0.13  0.17   1.00

# %%
pd.crosstab(df['Product'],[df['Education']], normalize=True, margins=True, margins_name='Total').round(2)
# Out:
# Education    12    13    14    15    16    18    20    21  Total
# Product
# KP281      0.01  0.02  0.17  0.02  0.22  0.01  0.00  0.00   0.44
# KP481      0.01  0.01  0.13  0.01  0.17  0.01  0.00  0.00   0.33
# KP781      0.00  0.00  0.01  0.00  0.08  0.11  0.01  0.02   0.22
# Total      0.02  0.03  0.31  0.03  0.47  0.13  0.01  0.02   1.00
